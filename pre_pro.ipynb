# %%
import pandas as pd

# %%
all_snack = pd.read_csv('./source/snack_500_rev_7.csv')
attractive_snack = pd.read_csv('./source/Attractive_snack.csv')

# %%
all_snack.head()
# Out:
#                                              Column1 Column2  \
# 0  http://allrecipes.com/recipe/blt-on-a-stick/de...   Snack
# 1  http://allrecipes.com/recipe/grilled-eggplant-...   Snack
# 2  http://allrecipes.com/recipe/honey-roasted-pea...   Snack
# 3  http://allrecipes.com/recipe/horseradish-devil...   Snack
# 4  http://allrecipes.com/recipe/jerrys-wings/deta...   Snack
#
#                                              Column3  \
# 0  http://images.media-allrecipes.com/userphotos/...
# 1  http://images.media-allrecipes.com/userphotos/...
# 2  http://images.media-allrecipes.com/userphotos/...
# 3  http://images.media-allrecipes.com/userphotos/...
# 4  http://images.media-allrecipes.com/userphotos/...
#
#                                  Column4  Column5  \
# 0                         BLT on a Stick       72
# 1               Grilled Eggplant Rollups      148
# 2                  Honey Roasted Peanuts      239
# 3  Horseradish Cream Cheese Deviled Eggs       79
# ...

# %%
attractive_snack.head()
# Out:
#                                              Column1 Column2  \
# 0  http://allrecipes.com/recipe/raw-hummus/detail...   Snack
# 1  http://allrecipes.com/recipe/buffalo-chicken-s...   Snack
# 2  http://allrecipes.com/recipe/egg-roll-reuben-w...   Snack
# 3  http://allrecipes.com/recipe/enchilada-meatbal...   Snack
# 4  http://allrecipes.com/recipe/pork-dumplings/de...   Snack
#
#                                              Column3  \
# 0                 ./attractive_snacks/Raw Hummus.jpg
# 1  ./attractive_snacks/Buffalo Chicken Stuffed Sh...
# 2      ./attractive_snacks/Egg Roll Reuben Wraps.jpg
# 3        ./attractive_snacks/Enchilada Meatballs.jpg
# 4             ./attractive_snacks/Pork Dumplings.jpg
#
#                           Column4  Column5  \
# 0                      Raw Hummus       67
# 1  Buffalo Chicken Stuffed Shells      698
# 2           Egg Roll Reuben Wraps      286
# 3             Enchilada Meatballs      398
# 4                  Pork Dumplings      752
#
# ...

# %%
all_snack.loc[all_snack.Column4.isin(attractive_snack.Column4)][['Column3','Column4']].merge(attractive_snack, on='Column4').to_csv('./source/Attractive_snack_new.to_.csv', index=False)

# %%
all_pasta = pd.read_csv('./source/pasta_500_rev_7.csv')
attractive_pasta = pd.read_csv('./source/Attractive_pasta_new.csv')

# %%
all_pasta.head()
# Out:
#                                              Column1 Column2  \
# 0  http://allrecipes.com/recipe/angels-ravioli-al...   Pasta
# 1  http://allrecipes.com/recipe/baked-penne-with-...   Pasta
# 2  http://allrecipes.com/recipe/barbecue-lasagna/...   Pasta
# 3  http://allrecipes.com/recipe/bellas-mac-and-ch...   Pasta
# 4  http://allrecipes.com/recipe/chicken-and-bow-t...   Pasta
#
#                                              Column3  \
# 0  http://images.media-allrecipes.com/userphotos/...
# 1  http://images.media-allrecipes.com/userphotos/...
# 2  http://images.media-allrecipes.com/userphotos/...
# 3  http://images.media-allrecipes.com/userphotos/...
# 4  http://images.media-allrecipes.com/userphotos/...
#
#                                   Column4  Column5  \
# 0  Angel's Ravioli Alfredo with Mushrooms      516
# 1        Baked Penne with Italian Sausage      664
# 2                        Barbecue Lasagna      710
# 3                  Bella's Mac and Cheese      388
# ...

# %%
attractive_pasta.head()
# Out:
#                                              Column1 Column2  Column3  \
# 0  http://allrecipes.com/recipe/microwave-macaron...   Pasta      NaN
# 1  http://allrecipes.com/recipe/pasta-salad-ii/de...   Pasta      NaN
# 2  http://allrecipes.com/recipe/pearl-couscous-sa...   Pasta      NaN
# 3  http://allrecipes.com/recipe/turkey-macaroni-s...   Pasta      NaN
# 4  http://allrecipes.com/recipe/alysias-basic-mea...   Pasta      NaN
#
#                          Column4  Column5  \
# 0  Microwave Macaroni and Cheese      659
# 1                 Pasta Salad II      446
# 2           Pearl Couscous Salad      560
# 3          Turkey Macaroni Salad      858
# 4    Alysia's Basic Meat Lasagna      567
#
#                                              Column6  Column7 Column8 Column9  \
# 0  macaroni pasta,butter,onion,cheese,milk,salt,b...        4   31.2g     54g
# 1  rotini pasta,Monterey Jack cheese,olives,cucumber        8     15g   45.6g
# ...

# %%
all_pasta.loc[all_pasta.Column4.isin(attractive_pasta.Column4)][['Column3','Column4']].merge(attractive_pasta, on='Column4').to_csv('./source/Attractive_pasta_new_.csv', index=False)

# %%
all_salad = pd.read_csv('./source/salad_500_rev_7.csv')
attractive_salad = pd.read_csv('./source/Attractive_salad.csv')

# %%
all_pasta.loc[all_pasta.Column4.isin(attractive_pasta.Column4)][['Column3','Column4']].merge(attractive_pasta, on='Column4').to_csv('./source/Attractive_salad_new_.csv', index=False)

# %%
all_snack = pd.read_csv('./source/snack_500_rev_7.csv')
attractive_snack = pd.read_csv('./source/Attractive_snack.csv')

# %%
all_snack.loc[all_snack.Column4.isin(attractive_snack.Column4)][['Column3','Column4']].merge(attractive_snack, on='Column4').to_csv('./source/Attractive_snack_new_.csv', index=False)

# %%
all_dissert = pd.read_csv('./source/dessert_500_rev_7.csv')
attractive_dissert = pd.read_csv('./source/Attractive_dessert.csv')

all_dissert.loc[all_dissert.Column4.isin(attractive_snack.Column4)][['Column3','Column4']].merge(attractive_snack, on='Column4')
# .to_csv('./source/Attractive_dissert_new_.csv', index=False)

# %%
attractive_snack.loc[attractive_snack.Column4.isin(all_dissert.Column4)]
# Out:
# Empty DataFrame
# Columns: [Column1, Column2, Column3, Column4, Column5, Column6, Column7, Column8, Column9, Column10, Column11, Column12, Column13, Column14, Column15, Column16, Column17, Column18, Column19, Column20, Column21, Column22, Column23, Column24, Column25, Column26, Column27, Column28, Column29, Column30, Column31, Column32, Column33, Column34, Column35]
# Index: []
#
# [0 rows x 35 columns]

# %%
all_dissert = all_dissert[['Column3','Column4']]

# %%
dissert = all_dissert.merge(attractive_dissert, on='Column4')

# %%
dissert.to_csv('./source/Attractive_dissert_new_.csv', index=False)
